# %% [markdown]
# 1. Create a random 4x4 array from an exponential distribution. Refer numpy functions.

# %%
import numpy as np

# Create a random 4x4 array from an exponential distribution
exponential_array = np.random.exponential(scale=1.0, size=(4, 4))

# Display the array
print(exponential_array)
# Out:
# [[0.31232681 1.41488979 0.1877636  0.30444571]
#  [2.41325389 1.72950279 0.36926192 0.32071382]
#  [2.33026959 0.19611139 1.69408392 1.66654825]
#  [0.92634361 0.22981598 2.13080772 1.30479596]]

# %% [markdown]
# 2. Create a random 100000x1 array from the same exponential distribution and visualize the
# distribution histogram along with uniform and normal distributions. Use the code given
# below and do the necessary changes. Change the number of bins and the plot view to make
# the visualization better.

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.rand(200000), density=True, bins=100, histtype="step", color="blue",
label="rand")
plt.axis([-2.5, 2.5, 0, 1.2])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# 3. Using matplotlib, plot the Z = X**2 + Y**2 in a 3D plot. Limit the x and y values to [-5, 5]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a grid of x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Compute Z = X² + Y²
Z = X**2 + Y**2

# Create a 3D plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(X, Y, Z, cmap='viridis')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Plot of Z = X² + Y²')

plt.show()

# %% [markdown]
# 4. Calculate the pearson standard coefficient and spearman rank correlation for the [HP,
# Attack, Defense, Sp. Ark, Sp. Def, Speed] features in the seaborn tutorial.ipynb. Visualize the
# results using heatmaps. Make sure the values are displaced in the heatmap as well.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Download the dataset
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv

# Load the dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# Select the relevant features
features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
stats_df = df[features]

# Calculate Pearson correlation
pearson_corr = stats_df.corr(method='pearson')

# Calculate Spearman rank correlation
spearman_corr = stats_df.corr(method='spearman')

# Plot Pearson correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Pearson Correlation Heatmap')
plt.show()

# Plot Spearman rank correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Spearman Rank Correlation Heatmap')
plt.show()
